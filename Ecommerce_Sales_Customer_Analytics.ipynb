# %% [markdown]
# <a href="https://colab.research.google.com/github/Cursed-realm/Ecommerce-Sales-Customer-Analytics/blob/main/Ecommerce_Sales_Customer_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Day 1: Project Setup & Data Understanding
# Set up the E-Commerce Analytics project, understood the business problem and dataset structure, and established the GitHub workflow

# %%
from google.colab import userdata
TOKEN = userdata.get('GITHUB_TOKEN')
USERNAME = "cursed-realm"
REPO_NAME = "Ecommerce-Sales-Customer-Analytics"
EMAIL = "adityasharmaagra2003@gmail.com"

# !git config --global user.name "{USERNAME}"
# !git config --global user.email "{EMAIL}"
# !git clone "https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git"
# %cd {REPO_NAME}
# Out:
# Cloning into 'Ecommerce-Sales-Customer-Analytics'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/Ecommerce-Sales-Customer-Analytics

# %%
import pandas as pd

customers = pd.read_csv("olist_customers_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
payments = pd.read_csv("olist_order_payments_dataset.csv")
reviews = pd.read_csv("olist_order_reviews_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
category_translation = pd.read_csv("product_category_name_translation.csv")

datasets = {
    "customers": customers,
    "orders": orders,
    "order_items": order_items,
    "products": products,
    "payments": payments,
    "reviews": reviews,
    "sellers": sellers,
    "geolocation": geolocation,
    "category_translation": category_translation
}

# %%
for name, df in datasets.items():
    print(f"{name:22} → {df.shape[0]:,} rows × {df.shape[1]} columns")
# Out:
# customers              → 99,441 rows × 5 columns
# orders                 → 99,441 rows × 8 columns
# order_items            → 112,650 rows × 7 columns
# products               → 32,951 rows × 9 columns
# payments               → 103,886 rows × 5 columns
# reviews                → 99,224 rows × 7 columns
# sellers                → 3,095 rows × 4 columns
# geolocation            → 1,000,163 rows × 5 columns
# category_translation   → 71 rows × 2 columns

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    print(df.info())
# Out:
# customers
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# None
#
# orders
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
# ...

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   olist_customers_dataset.csv
# 	new file:   olist_geolocation_dataset.csv
# 	new file:   olist_order_items_dataset.csv
# 	new file:   olist_order_payments_dataset.csv
# 	new file:   olist_order_reviews_dataset.csv
# 	new file:   olist_orders_dataset.csv
# 	new file:   olist_products_dataset.csv
# 	new file:   olist_sellers_dataset.csv
# 	new file:   product_category_name_translation.csv

# %%
# !git add .

# %%
# !git commit -m "Day 1: loaded and explored Olist e-commerce dataset (9 tables), understood data grain, investigated missing delivery dates against order_status"
# Out:
# [main 9ec8ae5] Day 1: loaded and explored Olist e-commerce dataset (9 tables), understood data grain, investigated missing delivery dates against order_status
#  9 files changed, 1556426 insertions(+)
#  create mode 100644 olist_customers_dataset.csv
#  create mode 100644 olist_geolocation_dataset.csv
#  create mode 100644 olist_order_items_dataset.csv
#  create mode 100644 olist_order_payments_dataset.csv
#  create mode 100644 olist_order_reviews_dataset.csv
#  create mode 100644 olist_orders_dataset.csv
#  create mode 100644 olist_products_dataset.csv
#  create mode 100644 olist_sellers_dataset.csv
#  create mode 100644 product_category_name_translation.csv

# %%
# !git push
# Out:
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 42.32 MiB | 4.28 MiB/s, done.
# Total 11 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File olist_geolocation_dataset.csv is 58.44 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Cursed-realm/Ecommerce-Sales-Customer-Analytics.git
# To https://github.com/cursed-realm/Ecommerce-Sales-Customer-Analytics.git
#    7515cff..9ec8ae5  main -> main
